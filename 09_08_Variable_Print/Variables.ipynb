# %% [markdown]
# # Variables

# %%
Python has no command to declare variable
Used to store value(numerical, dict, sequence)

No need to specify data types of variables

equal operator is used to assign value to variable

# %%
string = "python"
a = 100
b = 10.35
l1 = [3,5,7,8]
type(b)
c = 4 + 5j
print(type(c))
type(c)
# Out:
# <class 'complex'>
# complex

# %%
abc = 200
print(abc)
# Out:
# 200

# %%
abc = 200
print(abc)
# Out:
# 200

# %% [markdown]
# # Rules to Define Variable

# %% [raw]
# 1. Variable name must start with alphabet(A-Z, a-z) or underscore(_)
#
# 2. Case Sensitive (name, NAME , Name all variables are different )
#
# 3. All char may be alphanumeric (a-z, A-Z, 0-9) or underscore(_)
#
# 4. Must not contain any special character(@, #, $, %, ^, &, * ,dot,..)
#
# 5. Do not use reserved words (any, if, max, elif, class, def , break, continue, try, except, ...)

# %%
myvar = 1000
__myvar = 2000
print(__myvar)

MyVar = 3000
MyVar
# Out:
# 2000
# 3000

# %%
MyVar = 'python'
myvar = 'Class'
print(MyVar)
print(myvar)
# Out:
# python
# Class

# %%
Myvar = 'python'
myvar = 'Class'
print(Myvar)
print(myvar)
# Out:
# python
# Class

# %%
myvar = 'python'
myvar = 'Class'
print(myvar)
print(myvar)
# Out:
# Class
# Class

# %%
myvar = "python"
myvar = "Class"
print(myvar)
print(myvar)
# Out:
# Class
# Class

# %%
a = "python"  # Assigning string to a variable
print(a)  # 'python'
a = "Class"  # 'Class'
print(a)
print(a)
# Out:
# python
# Class
# Class

# %%
x = 200
print(x)

x = 300
print(x)

print(x)
# Out:
# 200
# 300
# 300

# %%
MyVar ='Data Science'
print(MyVar)

MyVar123 ='Machine Learning'
print(MyVar123)
# Out:
# Data Science
# Machine Learning

# %%
MyVar_123 ='Machine Learning'
print(MyVar_123)
# Out:
# Machine Learning

# %%
My_Var_123 ='Machine Learning'
print(My_Var_123)
# Out:
# Machine Learning

# %%
# My@Var = 'Deep Learning'
My_Var = 'Deep Learning'

# %%
myvar1234 = 'Python and Data science'
myvar1234
# Out:
# 'Python and Data science'

# %%
myvar_1234 = 'Python and Data science'
myvar_1234
# Out:
# 'Python and Data science'

# %%
1234myvar = 'Python and Data science'
1234myvar
# Out:
#   File "<ipython-input-48-b160985dcaff>", line 1
#     1234myvar = 'Python and Data science'
#         ^
# SyntaxError: invalid syntax

# %%
myvar.1234 = 'Python and Data science'
myvar.1234
# Out:
#   File "<ipython-input-49-f9661e0434ca>", line 1
#     myvar.1234 = 'Python and Data science'
#          ^
# SyntaxError: invalid syntax

# %%
if = 'Python'
elif ='python'
import = 'Python'
# Out:
#   File "<ipython-input-52-efc07f5b9db1>", line 2
#     elif ='python'
#     ^
# SyntaxError: invalid syntax

# %%
import = 'Python'
# Out:
#   File "<ipython-input-54-3b2e15c195d0>", line 1
#     import = 'Python'
#            ^
# SyntaxError: invalid syntax

# %% [raw]
# myvar
# myVar
# MYVAR
# MyVar
# My_Var
# My__Var
# My^var  # Invalid
# My&Var  # Invalid
# myvariable
# Myvar1234
# 123Myvar  # Invalid
# a
# b
# a_b
# abc
# _abc
# A_B_C
# myV@r  # Invalid
# any  # Invalid
# MYVAR123
# import  # Invalid
# elif # Invalid
# Any # Valid
# Import # Valid

# %% [markdown]
# # Types of Variable

# %%
1. global Varible # Declared outside function
2. Local Variable # Declared inside function

# %%
a = 200  # global Var

def my_fun():  # User defined function
    x1 = 300  # Local Variable
    print('x1 == ',x1)

my_fun() # Calling function  

print(a)
print(x1)
# Out:
# x1 ==  300
# 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-b9f34f32e42f> in <module>
#       8
#       9 print(a)
# ---> 10 print(x1)
#
# NameError: name 'x1' is not defined

# %% [markdown]
# # Assigning single value to multiple variable

# %%
x = 10
y = 10
z = 10
print(f"x = {x} , y == {y}, z === {z}")
# Out:
# x = 10 , y == 10, z === 10

# %%
x = 10
y = 10
z = 10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
a = b = c = 50
print(a)
print(b)
print(c)
# Out:
# 50
# 50
# 50

# %%
a = b = c = 'Data'
print(a)
print(b)
print(c)
print(a,b,c)
# Out:
# Data
# Data
# Data
# Data Data Data

# %% [markdown]
# # Multiple Values to multiple variable

# %%
a = 10
b = 20
c = 'Python'
print(a,b,c)
# Out:
# 10 20 Python

# %%
a = 10 ; b = 20 ; c = 'Python'
print(a,b,c)
# Out:
# 10 20 Python

# %%
l1 = [] ; l2 = []; l3 = []; l4 = []

# %%
type(l1)
# Out:
# list

# %%
a = 4 ;  b = 5
print(a,b)
# Out:
# 4 5

# %% [markdown]
# # Delete Variable

# %%
string = 'Pune'
print(string)

print(string)

del string
# Out:
# Pune
# Pune

# %%
a = 3
b = 4
print(a,b)
del a,b
print(b)
# Out:
# 3 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-b4c4c5efc444> in <module>
#       3 print(a,b)
#       4 del a,b
# ----> 5 print(b)
#
# NameError: name 'b' is not defined

# %%
list1 = [2,3,4,10.5,4.5,'python']
print(len(list1))
del list1[2]
print(list1)
print(len(list1))
# Out:
# 6
# [2, 3, 10.5, 4.5, 'python']
# 5

# %%
a = 10
b = 20
print(a,b)
# Out:
# 10 20

# %%
a,b = 10,20

print(a,b)
# Out:
# 10 20

# %%
a,b,c = 10,20,30

print(a,b,c)
# Out:
# 10 20 30
