# %%
import time
import datetime

# %% [raw]
# d1 = 16-06-2018
# d2 = 16-June-2018
# d3 = '16/06/2018'
# d4 = '16 Jun 2018' # '20 Jul 2020'
# d5 = '2018/06/2018'
#
# '2018-06-16'

# %% [raw]
# Document_Name       Upload Document Time       Status
# PAN_Rahul           2021-10-12 08:11           Success
# PAN_Akash           2021-10-12 08:13           Failure

# %%
KNN 
Decision Tree
Random Forest

# %%
start_time = time.time()
print("start_time",start_time)

for i in range(50000000):
    pass

end_time = time.time()
print("Time taken to execute for loop is :",end_time - start_time)
# Out:
# start_time 1634050074.8238373
# Time taken to execute for loop is : 3.385991096496582

# %%
def test_time():
    for i in range(100000000):
        pass
    for i in range(100000000):
        pass
    
start_time = time.time()
print("start_time",start_time)

test_time()

end_time = time.time()
print("Time taken to execute for loop is :",end_time - start_time)
# Out:
# start_time 1634050180.3971214
# Time taken to execute for loop is : 5.051443576812744

# %%
def test_time():
    for i in range(100000000):
        pass
    for i in range(100000000):
        pass
    
start_time = time.time()

test_time()

end_time = time.time()

total_time = end_time - start_time
print("Time taken to execute for loop is :",total_time)
# Out:
# Time taken to execute for loop is : 5.088250160217285

# %%
def test_time():
    for i in range(100000000):
        pass
    for i in range(100000000):
        pass
    
start_time = time.time()

test_time()

total_time = time.time() - start_time
print("Time taken to execute for loop is :",total_time)
# Out:
# Time taken to execute for loop is : 5.539448499679565

# %%
time.time() # 1970
# Out:
# 1634050406.543206

# %%
time.time() # 1970
# Out:
# 1634050421.3765392

# %%
time.perf_counter()
# Out:
# 1374.4422625

# %%
time.perf_counter()
# Out:
# 1377.1806475

# %% [markdown]
# # time.perf_counter()

# %%
# Performance Counter

# %%
def test_time():
    for i in range(100000000):
        pass
    for i in range(100000000):
        pass
    
start_time = time.perf_counter()

test_time()

total_time = time.perf_counter() - start_time
print("Time taken to execute for loop is :",total_time)
# Out:
# Time taken to execute for loop is : 5.120441100000107

# %% [markdown]
# # DateTime

# %% [markdown]
# ### 1. Current DateTime

# %%
import datetime

current_time = datetime.datetime.now()
print("current_time :",current_time)
# Out:
# current_time : 2021-10-12 20:26:09.226375

# %%
current_time = datetime.datetime.today()
print("current_time :",current_time)
# Out:
# current_time : 2021-10-12 20:26:39.496409

# %%
from datetime import datetime

current_time = datetime.now()
print("current_time :",current_time)
# Out:
# current_time : 2021-10-12 20:27:31.428672

# %%
import datetime
current_time = datetime.datetime.now()
print("current_time :",current_time)
# Out:
# current_time : 2021-10-12 20:28:19.138117

# %%
current_time.year
# Out:
# 2021

# %%
current_time.month
# Out:
# 10

# %%
current_time.day
# Out:
# 12

# %%
current_time.hour
# Out:
# 20

# %%
current_time.minute
# Out:
# 28

# %%
print(current_time.date())
# Out:
# 2021-10-12

# %%
print(current_time.time())
# Out:
# 20:28:19.138117

# %% [markdown]
# # timeDelta

# %%
print(current_time)
# Out:
# 2021-10-12 20:28:19.138117

# %%
day = current_time + datetime.timedelta(days = -30)
print(day)
# Out:
# 2021-09-12 20:28:19.138117

# %%
day = current_time + datetime.timedelta(days = 30)
print(day)
# Out:
# 2021-11-11 20:28:19.138117

# %%
day = current_time + datetime.timedelta(weeks = 2)
print(day)
# Out:
# 2021-10-26 20:28:19.138117

# %%
day = current_time + datetime.timedelta(weeks = -2)
print(day)
# Out:
# 2021-09-28 20:28:19.138117

# %%
day = current_time + datetime.timedelta(hours = 4)
print(day)
# Out:
# 2021-10-13 00:28:19.138117

# %%
current_time = datetime.datetime.now()
print("current_time :",current_time)
# Out:
# current_time : 2021-10-12 20:35:41.055239

# %%
day = current_time + datetime.timedelta(hours = 0)
print(day)
# Out:
# 2021-10-12 20:35:41.055239

# %% [markdown]
# ### last 10 days and next 10 days

# %%
current_date = datetime.datetime.now().date()
print("current_time :",current_date)

for i in range(1,11):
    day = current_time + datetime.timedelta(days = i)
    print(day.date())
    
for i in range(1,11):
    day = current_time + datetime.timedelta(days = -i)
    print(day.date())
# Out:
# current_time : 2021-10-12
# 2021-10-13
# 2021-10-14
# 2021-10-15
# 2021-10-16
# 2021-10-17
# 2021-10-18
# 2021-10-19
# 2021-10-20
# 2021-10-21
# 2021-10-22
# 2021-10-11
# 2021-10-10
# 2021-10-09
# 2021-10-08
# 2021-10-07
# 2021-10-06
# 2021-10-05
# 2021-10-04
# 2021-10-03
# 2021-10-02
