# %% [markdown]
# # OS Module

# %%
1. os.rename()
2. os.remove()  # To remove / delete file
3. os.rmdir()   # To remove empty folder
4. os.mkdir()   # To create folder
5. os.makedirs() # TO create folder 
6. os.getcwd()   # CWD
7. os.path.exists() # To check folder is exist or not
8. os.listdir() # List of files in folder
9. os.path.join() # To join two path
10. shutil.copy() # Copy Files from location to other
11. glob.glob() # Extract files with file extension

# %%
import os
os.mkdir('Data')

# %%
folder_path = "D:\\RahulK\\Velocity_Sep_21\\MACHINE_LEARNING\\Deep_Learning"
os.mkdir(folder_path)

# %%
folder_path = "D:\\RahulK\\Velocity_Sep_21\\MACHINE_LEARNING\\Deep_Learning"
os.makedirs(folder_path)

# %%
os.getcwd()
# Out:
# 'D:\\RahulK\\Velocity_Sep_21\\10_12'

# %% [markdown]
# ### Extract text files from directory

# %% [raw]
# text files
# pdf files
# images
# JSON files

# %%
path = 'Data'
files_list = os.listdir(path)  # List of all files
print(files_list)
# Out:
# ['1207_385_bank_statement11.pdf', '97_134_bank_statement21.pdf', 'autos_dataset.csv', 'Best Fit Line.gif', 'cost Function.png', 'Country_clusters.csv', 'credit-card.csv', 'Customers.csv', 'cv006_15448.txt', 'cv007_4968.txt', 'cv008_29435.txt', 'cv009_29592.txt', 'cv010_29198.txt', 'cv011_12166.txt', 'cv012_29576.txt', 'cv013_10159.txt', 'diabetes.csv', 'Gradient Descent.png', 'Gradient_Descent_Img.png', 'OS Module.ipynb']

# %%
text_files = []
pdf_file_list = []
image_list = []
csv_file_list = []
other_files = list()

for file in files_list:  # file = 'Best Fit Line.gif' str
    
    if file.endswith('.txt'):  # False
        file = 'Data\\' + file # 'Data\\cv008_29435.txt
        f = open(file,'r')
        text = f.read()
#         print(text)
        text_files.append(file)
        f.close()
        
    elif file.endswith('.pdf'):  # False
        print("::::::::::::::::::::::::::::",file)
        pdf_file_list.append(file)
        
    elif file.endswith('.csv'): # True
        csv_file_list.append(file)
        
    elif file.endswith('.png') or file.endswith('.gif'):  # False or True >> True
        image_list.append(file)
        
    else:
        other_files.append(file)

print("\nPDF files are :\n",pdf_file_list)
print("\nCSV files are :\n",csv_file_list)
print("\nImages  are :\n",image_list)
print("\nText files are :\n",text_files)
print("\nOther Files",other_files)
# Out:
# :::::::::::::::::::::::::::: 1207_385_bank_statement11.pdf
# :::::::::::::::::::::::::::: 97_134_bank_statement21.pdf
#
# PDF files are :
#  ['1207_385_bank_statement11.pdf', '97_134_bank_statement21.pdf']
#
# CSV files are :
#  ['autos_dataset.csv', 'Country_clusters.csv', 'credit-card.csv', 'Customers.csv', 'diabetes.csv']
#
# Images  are :
#  ['Best Fit Line.gif', 'cost Function.png', 'Gradient Descent.png', 'Gradient_Descent_Img.png']
#
# Text files are :
#  ['Data\\cv006_15448.txt', 'Data\\cv007_4968.txt', 'Data\\cv008_29435.txt', 'Data\\cv009_29592.txt', 'Data\\cv010_29198.txt', 'Data\\cv011_12166.txt', 'Data\\cv012_29576.txt', 'Data\\cv013_10159.txt']
#
# Other Files ['OS Module.ipynb']

# %%
f =open('Data\\cv010_29198.txt','r')
text = f.read()
# print(text)
f.close()

# %%
# D:\cv012_29576.txt
f =open('D:\\cv012_29576.txt','r')
text = f.read()
# print(text)
f.close()

# %%
file_path = os.getcwd() + '\\Data\\' + 'cv012_29576.txt'
print(file_path)
f =open(file_path,'r')
text = f.read()
# print(text)
f.close()
# Out:
# D:\RahulK\Velocity_Sep_21\10_12\Data\cv012_29576.txt

# %%
linux_file_path = "D:/RahulK/Velocity_Sep_21/10_12/Data/cv012_29576.txt"

# %% [markdown]
# # glob

# %%
import glob

# %%
path = 'Data'

files = os.listdir(path)
print(files)
# Out:
# ['1207_385_bank_statement11.pdf', '97_134_bank_statement21.pdf', 'autos_dataset.csv', 'Best Fit Line.gif', 'cost Function.png', 'Country_clusters.csv', 'credit-card.csv', 'Customers.csv', 'cv006_15448.txt', 'cv007_4968.txt', 'cv008_29435.txt', 'cv009_29592.txt', 'cv010_29198.txt', 'cv011_12166.txt', 'cv012_29576.txt', 'cv013_10159.txt', 'diabetes.csv', 'Gradient Descent.png', 'Gradient_Descent_Img.png', 'OS Module.ipynb']

# %%
path = 'Data\\'
files = glob.glob(path + "*.pdf")
print(files)
# Out:
# ['Data\\1207_385_bank_statement11.pdf', 'Data\\97_134_bank_statement21.pdf']

# %%
text_file_list = glob.glob(path + "*.txt")
for text_file in text_file_list:
    print(text_file)
    f = open(text_file,'r')
    text = f.read()
#     print("+++++++++++++++++++++++++++++++++++++++++++++++++\n",text)
    f.close()
# Out:
# Data\cv006_15448.txt
# Data\cv007_4968.txt
# Data\cv008_29435.txt
# Data\cv009_29592.txt
# Data\cv010_29198.txt
# Data\cv011_12166.txt
# Data\cv012_29576.txt
# Data\cv013_10159.txt

# %%
glob.glob(path + "*.csv")
# Out:
# ['Data\\autos_dataset.csv',
#  'Data\\Country_clusters.csv',
#  'Data\\credit-card.csv',
#  'Data\\Customers.csv',
#  'Data\\diabetes.csv']

# %% [markdown]
# # Shutil

# %%
import shutil
source = "Data\\cv006_15448.txt"
destination = "python\\cv006_15448.txt"
shutil.copy(source, destination)
# Out:
# 'python\\cv006_15448.txt'
